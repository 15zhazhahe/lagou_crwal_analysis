# %% [markdown]
# # 从数据库获取数据

# %%
# 导入数据
import pandas as pd
import pymysql
db = pymysql.connect(host="localhost", user="root", passwd='lvoe07', db="lagou_crawl", charset='utf8')
sql = '''
    select positionName,companyShortName,
    min_salary,max_salary,avg_salary,
    companyLabelList,job_description,industryField,companySize,
    city,education,workyear,firstType
    from lagou_crawl.position_info;
    '''
data = pd.read_sql(sql, db)
data['count'] = 1
db.close()

# %%
data
# Out:
#                   positionName companyShortName  min_salary  max_salary  \
# 0                      数据挖掘工程师         我来贷WeLab        25.0        35.0
# 1                      数据挖掘工程师               陌陌        20.0        40.0
# 2                         数据挖掘               悠易        20.0        35.0
# 3                         数据挖掘             京东金融        20.0        35.0
# 4                         数据挖掘             通联数据        15.0        30.0
# 5                    数据挖掘研发工程师             酷云互动        20.0        40.0
# 6                         数据挖掘              爱云校        15.0        30.0
# 7                      数据挖掘工程师              齐家网        15.0        30.0
# 8                 数据挖掘/机器学习工程师              360        25.0        35.0
# 9                      数据挖掘工程师             美团点评        20.0        40.0
# 10                高级算法与数据挖掘工程师               无秘        25.0        50.0
# 11                        数据挖掘          LinkDoc        20.0        40.0
# 12                        数据挖掘               无秘        25.0        50.0
# 13                        数据挖掘        集奥聚合（GEO）        18.0        30.0
# 14                     数据挖掘工程师             通联数据        18.0        30.0
# 15                   数据挖掘开发工程师       Gridsum 国双        15.0        30.0
# 16                     数据挖掘工程师         链家上海研发中心        15.0        25.0
# 17                     数据挖掘工程师             恺英网络        20.0        40.0
# 18                     数据挖掘工程师              爱云校        20.0        40.0
# 19                   数据挖掘高级工程师              好未来        18.0        30.0
# 20                高级算法与数据挖掘工程师               无秘        25.0        50.0
# 21                        数据挖掘            roobo        30.0        50.0
# 22                        数据挖掘           Hypers        15.0        30.0
# 23                        数据挖掘       KLOOK 客路旅行        10.0        20.0
# 24                        数据挖掘            宏力达科技         6.0         8.0
# 25                   网页搜索-数据挖掘               搜狗        20.0        40.0
# 26                     数据挖掘工程师             同程旅游        20.0        35.0
# 27                   数据挖掘开发工程师         iPIN.com        20.0        40.0
# 28                垂直搜索-数据挖掘研究员               搜狗        15.0        25.0
# 29                    高级数据挖掘专家               in        20.0        30.0
# ..                         ...              ...         ...         ...
# 420                    数据挖掘工程师              功夫贷        10.0        20.0
# 421                    数据挖掘工程师       Edison Inc        15.0        25.0
# 422         数据分析师/数据挖掘/数据建模工程师             浙江保融        14.0        26.0
# 423                     数据挖掘方向             美团点评        25.0        30.0
# 424                    数据挖掘工程师             科达股份        10.0        15.0
# 425                    数据挖掘分析师              易企秀        20.0        35.0
# 426                     数据挖掘方向             美团点评        25.0        30.0
# 427                    数据挖掘工程师              蚂蜂窝        20.0        30.0
# 428                    数据挖掘工程师               鼎阅        15.0        30.0
# 429                    数据挖掘工程师             京东商城        15.0        30.0
# 430                    数据挖掘工程师             京东商城        15.0        30.0
# 431                    数据挖掘工程师               快手        20.0        40.0
# 432                       数据挖掘             和创金服        25.0        50.0
# 433                     数据挖掘经理             达飞金控        13.0        25.0
# 434                    数据挖掘工程师             柏睿数据        20.0        40.0
# 435                      数据挖掘师          tap4fun        15.0        30.0
# 436  数据挖掘&amp;机器学习算法高级工程师/技术专家          阿里巴巴—高德        20.0        40.0
# 437                     数据挖掘经理             京东金融        20.0        40.0
# 438                    数据挖掘工程师          多点Dmall        15.0        25.0
# 439         数据挖掘专家(J180117010)             滴滴出行        15.0        30.0
# 440                    数据挖掘工程师              快商通        10.0        20.0
# 441                  数据挖掘算法工程师          Minieye        15.0        30.0
# 442                    数据挖掘工程师             传音控股        18.0        36.0
# 443                  高级数据挖掘工程师            我查查信息        25.0        50.0
# 444                    数据挖掘工程师               腾讯        20.0        40.0
# 445                    数据挖掘工程师             小库科技        20.0        30.0
# 446               数据仓库/数据挖掘工程师             菜鸟网络        20.0        40.0
# 447               数据仓库/数据挖掘工程师             菜鸟网络        20.0        40.0
# 448                     数据挖掘专家             阿里影业        30.0        50.0
# 449                    数据挖掘工程师              和信贷        10.0        20.0
#
#      avg_salary         companyLabelList  \
# 0          30.0      年底双薪,五险一金,带薪年假,扁平管理
# 1          30.0       岗位晋升,帅哥多,管理规范,技能培训
# 2          27.5      节日礼物,技能培训,绩效奖金,年度旅游
# 3          27.5     供应链金融,消费金融,众筹业务,支付业务
# 4          22.5      五险一金,通讯津贴,带薪年假,节日礼物
# 5          30.0    技能培训,节日礼物,年度旅游,丰盛的早午餐
# 6          22.5      技能培训,节日礼物,股票期权,带薪年假
# 7          22.5      午餐补助,带薪年假,绩效奖金,交通补助
# 8          30.0                     null
# 9          30.0       技能培训,绩效奖金,岗位晋升,领导好
# 10         37.5       高速增长,股票期权,小而精,扁平管理
# 11         30.0                     null
# 12         37.5       高速增长,股票期权,小而精,扁平管理
# 13         24.0      五险一金,节日礼物,弹性工作,定期体检
# 14         24.0      五险一金,通讯津贴,带薪年假,节日礼物
# 15         22.5      年度旅游,节日礼物,年底双薪,带薪年假
# 16         20.0      技能培训,带薪年假,年度旅游,岗位晋升
# 17         30.0           游戏公司,页游,手游,互联网
# 18         30.0      技能培训,节日礼物,股票期权,带薪年假
# 19         24.0      上市公司,领军企业,五险一金,住福计划
# 20         37.5       高速增长,股票期权,小而精,扁平管理
# 21         40.0      年底双薪,节日礼物,技能培训,年度旅游
# 22         22.5      绩效奖金,五险一金,带薪年假,年度旅游
# 23         15.0  零食水果供应,带薪年假,绩效奖金,程序猿鼓励妹
# 24          7.0                     null
# 25         30.0      岗位晋升,扁平管理,管理规范,精英团队
# 26         27.5      绩效奖金,股票期权,年底双薪,五险一金
# 27         30.0     发展迅猛,股票期权,管饭+零食,数据驱动
# 28         20.0      岗位晋升,扁平管理,管理规范,精英团队
# 29         25.0      节日礼物,股票期权,年度旅游,岗位晋升
# ..          ...                      ...
# 420        15.0       节日礼物,股票期权,带薪年假,美女多
# 421        20.0      股票期权,带薪年假,定期体检,绩效奖金
# 422        20.0      年底双薪,节日礼物,岗位晋升,通讯津贴
# 423        27.5       技能培训,绩效奖金,岗位晋升,领导好
# 424        12.5                     null
# 425        27.5      股票期权,年度旅游,扁平管理,七险一金
# 426        27.5       技能培训,绩效奖金,岗位晋升,领导好
# 427        25.0       弹性工作,扁平管理,氛围好,年度体检
# 428        22.5                     null
# 429        22.5    免费班车,子女教育计划,安居计划,救助基金
# 430        22.5    免费班车,子女教育计划,安居计划,救助基金
# 431        30.0      股票期权,弹性工作,定期体检,岗位晋升
# 432        37.5      技能培训,节日礼物,带薪年假,绩效奖金
# 433        19.0      节日礼物,年底双薪,股票期权,带薪年假
# 434        30.0      股票期权,专项奖金,带薪年假,弹性工作
# 435        22.5      技能培训,节日礼物,年底双薪,带薪年假
# 436        30.0        弹性工作,帅哥多,美女多,五险一金
# 437        30.0     供应链金融,消费金融,众筹业务,支付业务
# 438        20.0      技能培训,年底双薪,节日礼物,绩效奖金
# 439        22.5      弹性工作,节日礼物,岗位晋升,技能培训
# 440        15.0                     null
# 441        22.5      无人驾驶,国际标准,车厂合作,海归团队
# 442        27.0      技能培训,专项奖金,带薪年假,年度旅游
# 443        37.5                     null
# 444        30.0      免费班车,成长空间,年度旅游,岗位晋升
# 445        25.0       股票期权,带薪年假,不打卡,扁平管理
# 446        30.0      股票期权,五险一金,带薪年假,免费班车
# 447        30.0      股票期权,五险一金,带薪年假,免费班车
# 448        40.0      股票期权,带薪年假,年度旅游,定期体检
# 449        15.0      节日礼物,专项奖金,股票期权,绩效奖金
#
#                                        job_description industryField  \
# 0    一、数据挖掘工程师岗位职责:1、负责数据仓库的创建和管理，创建ETL平台，负责将原始数据转换...            金融
# 1    工作职责：1、基于大规模用户数据，运用机器学习/数据挖掘的理论和方法，建立和优化通用或特定领...          社交网络
# 2    职责：1．基于海量数据的广告业务数据分析；2．根据广告反馈数据，对广告投放进行数据建模，包括...          广告营销
# 3    职位描述:1、构建风险计量模型对业务风险进行定性与定量评估；2、建立针对用户/商户/交易欺诈...            金融
# 4    岗位职责1.    利用机器学习和NLP技术从海量异构数据中进行有价值金融信息的挖掘和整合；...            金融
# 5    岗位职责：  运用机器学习、数据挖掘技术判别识别  主要工作内容包括：  1.通过对数据的敏...          数据服务
# 6    工作职责：1、根据需求文档完成功能设计、开发与测试 2、分析与解决线上问题，定位线上服务瓶颈...            教育
# 7    岗位职责：1．搭建大规模数据挖掘平台，开发创新性算法和技术；2．根据需求，制定数据挖掘项目计...           O2O
# 8    【奇虎360搜索团队】【机器学习/数据挖掘工程师】-北京工作职责：负责query意图分析、排...            游戏
# 9    数据挖掘工程师工作职责：1、结合具体业务场景，发现潜在的特征模型，挖掘现有数据的价值；2、对...           O2O
# 10   职位描述从事各种机器学习、数据挖掘算法等工作，改进金融风控模型。 职位要求1、非常扎实的数学...            金融
# 11   数据挖掘及机器学习研究员岗位职责1、利用数据挖掘、机器学习相关算法，解决核心业务需求2、基于...          医疗健康
# 12   收集、分析、理解数据，改进风控模型。要求：1、对数据敏感，熟悉特征工程2、掌握至少一款数据分...            金融
# 13   岗位职责1. 了解客户需求，对数据分析产品进行总体架构设计。 2. 根据需求对核心算法进行优...          数据服务
# 14   职位描述：1. 利用机器学习和NLP技术从海量异构数据中进行有价值金融信息的挖掘和整合，提供...            金融
# 15   【职责描述】 与业务专家合作，利用数理统计、数据挖掘的理论和方法解决实际问题，优化业务结果，...          企业服务
# 16   岗位职责： 1、负责公司相关数据模型产品的模型设计以及开发等工作； 2、为公司业务提供模型算...          企业服务
# 17   职位描述：1、负责恺英网络各平台用户数据的挖掘和机器学习工作；2、负责平台产品之间关联分析及...            游戏
# 18   工作职责： 根据需求文档完成功能设计、开发与测试  分析与解决线上问题，定位线上服务瓶颈与调...            教育
# 19   岗位职责描述：1、根据自己对行业，以及公司业务的了解，独自承担复杂分析任务，并形成分析报告；...            教育
# 20   职位描述：从事各种机器学习、数据挖掘算法等工作，改进金融风控模型。职位要求:1、非常扎实的数...            金融
# 21   数据挖掘工程师【职责描述】1.负责公司相关机器学习算法的研究，包括目前较为流行的深度学习等2...         移动互联网
# 22   岗位职责：                                 1.负责基于Ha...         移动互联网
# 23   1. 搭建数据分析平台，定期生成数据报告2. 负责销售数据的分析和挖掘3. 负责推荐系统、广...            旅游
# 24   岗位职责：1、进行业务系统数据库的规划、设计、实施，设计并优化数据库物理建设方案；2、对数据...          电子商务
# 25   【项目介绍】复合搜索研究部作为搜狗最有底蕴的研究团队之一，承载着PC及WAP的网页搜索的所有...          数据服务
# 26   岗位描述：1. 基于用户数据，建立数据挖掘模型，分析用户特征属性，预测用户行为和个性化需求；...          电子商务
# 27   岗位职责：1、海量文本数据的建模与检索等相关研发工作；2、对数据信息进行深度挖掘和有效利用，...          数据服务
# 28   项目介绍：垂直搜索部下辖视频、图片、音乐、购物、小说、游戏、金融、汽车等众多垂直领域的产品线...          数据服务
# 29   岗位职责：1、使用数据挖掘技术对用户行为和用户关系进行分析，探究用户行为特征和兴趣点，并应用...          广告营销
# ..                                                 ...           ...
# 420  工作职责：1、基于公司海量数据，应用各类统计模型、机器学习方法建立数据模型；2、挖掘主题包含...            金融
# 421  工作职责:-负责邮件数据的提出、存储、挖掘与分析-实现产品经理提出的数据端的功能与需求，数据...          数据服务
# 422  我们志在推动保险公司资金流动性管理发展，助力保险行业财务人员从单纯结算会计岗向财务决策，财务...            金融
# 423  工作职责海量用户与商户数据挖掘建模，完善用户与商户画像的知识图谱建设对接会员营销系统业务，使...           O2O
# 424  职责描述：负责通用算法模型和数字广告专业算法模型的研究和设计工作 根据产品需求建立数据分析模...          广告营销
# 425  岗位名称：数据挖掘分析师1、 精通SQL，有较好的SQL性能调优经验2、 熟悉数据仓库各类建...         移动互联网
# 426  职责描述：海量用户与商户数据挖掘建模，完善用户与商户画像的知识图谱建设对接会员营销系统业务，...           O2O
# 427  岗位职责:1、负责蚂蜂窝数据挖掘核心技术研究和开发2、基于蚂蜂窝海量数据，构建用户，目的地，...            旅游
# 428  任职要求1、  有3年以上大数据体系ETL系统经验，搭建过自有数据清洗平台，熟悉相关开发、调...         移动互联网
# 429  岗位职责：1.  负责业务数据和项目相关需求的收集、整理和维护（e.g. 线上广告精准营销）...          电子商务
# 430  岗位职责：1.  负责业务数据和项目相关需求的收集、整理和维护（e.g. 线上广告精准营销）...          电子商务
# 431  职位描述：工作职责:1. 基于业务目标，分析和挖掘海量数据，发现用户行为模式与规律，优化用户...         移动互联网
# 432  岗位职责：     1、负责大数据量的用户消费、信贷、互联网行为等数据的处理、清洗和挖掘，并...          电子商务
# 433  岗位职责：1.带领团队制定现金贷账户管理策略，建立高质量的风险、客户流失、收益评估模型，并不...            金融
# 434  岗位职责：1)匹配金融反欺诈、安全策略、精准营销等业务场景，使用机器学习、文本挖掘、用户特征...          信息安全
# 435  岗位职责：1. 分析市场推广及运营相关数据；2. 针对市场推广需求，利用相关数据，设计基于数...            游戏
# 436  1. 本科及以上学历，计算机、数学等相关专业，至少有1年工作经验；2. 熟悉常用算法和数据结...         移动互联网
# 437  主要岗位职责：1、基于京东海量的数据基础，通过机器学习等手段，优化现有风控、反欺诈、账户安全...            金融
# 438  岗位职责1、 独立完成部分较小规模系统的详细设计和编码的任务，确保项目的进度和质量；2、 生...          电子商务
# 439  岗位职责1、基于公司大数据平台海量用户数据，运用数据挖掘的理论方法深入挖掘；2、基于产品与业...         移动互联网
# 440  职责描述：1.建设并维护包括数据仓储、清洗、检索以及模型训练的公共基础平台；2. 提供简要的...            其他
# 441  职位要求：1. 3年以上数据挖掘工作经验，熟悉相关的基础理论和常用算法，有丰富的实践经验。2...            硬件
# 442  算法工程师 岗位职责：1、推荐、流量、广告等业务中的算法设计及实现。2、内容资讯产品中，自然...            硬件
# 443  工作职责：1、负责客户端用户分群，用户画像等标签体系建设与优化；2、针对不同业务需求，建立和...         移动互联网
# 444  岗位职责:1、通过海量数据对用户广告的行为进行深入分析与洞察，提炼和发现业务规律，指导推荐模...            游戏
# 445  福利：免费午餐，五险一金，激励股权，带薪年假，年底三薪，免费零食，团队出游...团队：世界顶...         移动互联网
# 446  工作地点：北京/杭州职位描述：1 参与菜鸟数据仓库架构设计与数据开发，建设PB级共享的数据平...          电子商务
# 447  注意：工作地点在杭州职位描述：1 参与菜鸟数据仓库架构设计与数据开发，建设PB级共享的数据平...          电子商务
# 448  职位描述：1. 应用机器学习、文本挖掘等技术，对海量数据进行挖掘，发现其潜在关系，指导业务发...          文化娱乐
# 449  岗位职责：1.负责海量数据的清洗、加工、挖掘等工作；2.用户价值挖掘，用户兴趣偏好预测，用户...            金融
#
#     companySize city education workyear  firstType  count
# 0      150-500人   深圳        本科     3-5年         技术      1
# 1     500-2000人   北京        本科     1-3年         技术      1
# 2      150-500人   北京        本科       不限         技术      1
# 3       2000人以上   北京        本科    5-10年         技术      1
# 4      150-500人   北京        本科     1-3年         技术      1
# 5      150-500人   北京        本科     3-5年         技术      1
# 6      150-500人   北京        本科     1-3年         技术      1
# 7       2000人以上   上海        硕士     3-5年         技术      1
# 8       2000人以上   北京        本科     3-5年         技术      1
# 9       2000人以上   北京        本科     3-5年         技术      1
# 10     150-500人   深圳        硕士     3-5年         技术      1
# 11     150-500人   北京        硕士       不限         技术      1
# 12     150-500人   深圳        硕士     3-5年         技术      1
# 13     150-500人   北京        硕士     3-5年         技术      1
# 14     150-500人   上海        本科       不限         技术      1
# 15    500-2000人   北京        本科     3-5年         技术      1
# 16    500-2000人   上海        本科     3-5年         技术      1
# 17    500-2000人   上海        本科     3-5年         技术      1
# 18     150-500人   北京        本科     3-5年         技术      1
# 19      2000人以上   北京        本科     3-5年         技术      1
# 20     150-500人   深圳        本科     3-5年         技术      1
# 21     150-500人   北京        本科     3-5年         技术      1
# 22      50-150人   上海        本科       不限         技术      1
# 23     150-500人   深圳        本科     1-3年         技术      1
# 24      50-150人  哈尔滨        大专     3-5年         技术      1
# 25      2000人以上   北京        硕士     1-3年         技术      1
# 26      2000人以上   苏州        本科    5-10年         技术      1
# 27      50-150人   深圳        硕士     3-5年         技术      1
# 28      2000人以上   北京        本科     1-3年         技术      1
# 29     150-500人   杭州        本科       不限         技术      1
# ..          ...  ...       ...      ...        ...    ...
# 420    150-500人   杭州        本科       不限  开发/测试/运维类      1
# 421     50-150人   广州        本科     1-3年  开发/测试/运维类      1
# 422    150-500人   杭州        不限     3-5年  产品/需求/项目类      1
# 423     2000人以上   北京        本科     1-3年  开发/测试/运维类      1
# 424     2000人以上   北京        本科     1-3年  开发/测试/运维类      1
# 425    150-500人   北京        本科     3-5年  开发/测试/运维类      1
# 426     2000人以上   北京        本科     1-3年  开发/测试/运维类      1
# 427   500-2000人   北京        本科     1-3年  开发/测试/运维类      1
# 428     50-150人   北京        本科     3-5年  开发/测试/运维类      1
# 429     2000人以上   北京        本科     3-5年  开发/测试/运维类      1
# 430     2000人以上   上海        本科     3-5年  开发/测试/运维类      1
# 431   500-2000人   北京        本科     3-5年  开发/测试/运维类      1
# 432   500-2000人   北京        本科     3-5年  开发/测试/运维类      1
# 433     2000人以上   深圳        本科     3-5年  产品/需求/项目类      1
# 434     50-150人   北京        硕士     1-3年  开发/测试/运维类      1
# 435    150-500人   上海        本科     1-3年  开发/测试/运维类      1
# 436     2000人以上   北京        本科       不限  开发/测试/运维类      1
# 437     2000人以上   北京        硕士     3-5年  开发/测试/运维类      1
# 438   500-2000人   成都        本科     1-3年  开发/测试/运维类      1
# 439     2000人以上   北京        本科     3-5年         运营      1
# 440    150-500人   厦门        硕士     1-3年  开发/测试/运维类      1
# 441     50-150人   深圳        本科     3-5年  开发/测试/运维类      1
# 442   500-2000人   上海        本科     3-5年  开发/测试/运维类      1
# 443    150-500人   深圳        本科     3-5年  开发/测试/运维类      1
# 444     2000人以上   北京        硕士     1-3年  开发/测试/运维类      1
# 445      15-50人   深圳        本科     1-3年  开发/测试/运维类      1
# 446     2000人以上   北京        本科    5-10年  开发/测试/运维类      1
# 447     2000人以上   杭州        本科    5-10年  开发/测试/运维类      1
# 448     2000人以上   北京        本科     3-5年  开发/测试/运维类      1
# 449    150-500人   北京        硕士     3-5年  产品/需求/项目类      1
#
# [450 rows x 14 columns]

# %% [markdown]
# ## 根据行业进行分组,统计公司数量与岗位数量
# <p>industry_top10 = ['金融', '移动互联网', '数据服务', '电子商务', 'O2O', '企业服务', '教育', '游戏', '文化娱乐', '社交网络']</p>
# <p>job_count = [98, 66, 53, 47, 45, 27, 19, 18, 16, 15]</p>
# <p>company_count = [57, 42, 23, 31, 18, 18, 10, 12, 11, 11]</p>
# <p>job_per_com = [1.72, 1.57, 2.3, 1.52, 2.5, 1.5, 1.9, 1.5, 1.45, 1.36]</p>
#
# ### 出现最频繁的行业是金融

# %%
from pyecharts import Bar,Line,Overlap
# 按行业分类,按行业的出现频率降序排序
industry = data.groupby('industryField').agg({'positionName': pd.Series.count,'companyShortName': pd.Series.nunique})
industry = industry.sort_values(['positionName', 'companyShortName'], ascending=[0, 0])
# 取出出现最频繁的十个行业
industry_top10 = list(industry.index)[:10]
job_count = list(map(int, industry['positionName']))[:10]   # 职位计数
company_count = list(map(int, industry['companyShortName']))[:10]   # 公司计数
job_per_com = []    # 每个行业对该岗位的需求程度
for i in range(0, len(industry_top10)):
    job_per_com.append(round(job_count[i]/company_count[i], 2))

# %%
bar = Bar('行业分布TOP10', subtitle='行业-职位数/公司数')
bar.add("职位数量", x_axis=industry_top10, bar_category_gap=0,xaxis_interval = 0,
        y_axis=job_count, is_label_show=1)
bar.add("公司数量", is_label_show=1, datazoom_orient='vertical',
        x_axis=industry_top10, xaxis_rotate=-45, xaxis_interval = 0,
        y_axis=company_count, yaxis_name='职位数量',
        yaxis_force_interval=20, yaxis_name_gap=40,
        datazoom_type='both', bar_category_gap=20)

# 行业-job/com-Line,表明公司对数据分析的需求程度
line = Line()
line.add('', x_axis=industry_top10, y_axis=job_per_com,
        line_width=2, is_label_show=1,
        yaxis_max=5, yaxis_force_interval=1)


overlap = Overlap()
overlap.add(bar)
overlap.add(line, yaxis_index=1, is_add_yaxis=True)
overlap
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="b988cdcfb64f465e93f0953ec9b4e8fc" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('b988cdcfb64f465e93f0953ec9b4e8fc'));
# var option =  {
#     "toolbox": {
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 98,
#                 66,
#                 53,
#                 47,
#                 45,
#                 27,
#                 19,
#                 18,
#                 16,
#                 15
#             ],
#             "seriesId": 6769535,
#             "stack": "",
#             "barCategoryGap": 0,
#             "name": "\u804c\u4f4d\u6570\u91cf",
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "position": "top",
#                     "formatter": null,
#                     "show": 1
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "position": null,
#                     "show": true
#                 }
#             }
#         },
#         {
#             "type": "bar",
#             "data": [
#                 57,
#                 42,
#                 23,
#                 31,
#                 18,
#                 18,
#                 10,
#                 12,
#                 11,
#                 11
#             ],
#             "seriesId": 6769535,
#             "stack": "",
#             "barCategoryGap": 20,
#             "name": "\u516c\u53f8\u6570\u91cf",
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "position": "top",
#                     "formatter": null,
#                     "show": 1
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "position": null,
#                     "show": true
#                 }
#             }
#         },
#         {
#             "type": "line",
#             "stack": "",
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "position": "top",
#                     "formatter": null,
#                     "show": 1
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "position": null,
#                     "show": true
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "type": "solid",
#                     "width": 2,
#                     "curveness": 0,
#                     "color": null,
#                     "opacity": 1
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "data": [
#                 1.72,
#                 1.57,
#                 2.3,
#                 1.52,
#                 2.5,
#                 1.5,
#                 1.9,
#                 1.5,
#                 1.45,
#                 1.36
#             ],
#             "yAxisIndex": 1,
#             "areaStyle": {},
#             "seriesId": 6769535,
#             "smooth": false,
#             "name": "",
#             "markLine": {
#                 "data": []
#             },
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "step": false,
#             "showSymbol": true
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "nameGap": 40,
#             "nameLocation": "middle",
#             "position": null,
#             "max": null,
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "min": null,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 },
#                 "rotate": 0,
#                 "formatter": "{value} ",
#                 "margin": 8
#             },
#             "inverse": false,
#             "name": "\u804c\u4f4d\u6570\u91cf",
#             "show": true,
#             "interval": 20
#         },
#         {
#             "type": "value",
#             "nameGap": 25,
#             "nameLocation": "middle",
#             "position": null,
#             "max": 5,
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "min": null,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "formatter": "{value} ",
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 },
#                 "margin": 8
#             },
#             "inverse": false,
#             "name": "",
#             "show": true,
#             "interval": 1
#         }
#     ],
#     "xAxis": [
#         {
#             "type": "category",
#             "nameGap": 25,
#             "nameLocation": "middle",
#             "position": null,
#             "max": null,
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "min": null,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "margin": 8,
#                 "rotate": -45,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "data": [
#                 "\u91d1\u878d",
#                 "\u79fb\u52a8\u4e92\u8054\u7f51",
#                 "\u6570\u636e\u670d\u52a1",
#                 "\u7535\u5b50\u5546\u52a1",
#                 "O2O",
#                 "\u4f01\u4e1a\u670d\u52a1",
#                 "\u6559\u80b2",
#                 "\u6e38\u620f",
#                 "\u6587\u5316\u5a31\u4e50",
#                 "\u793e\u4ea4\u7f51\u7edc"
#             ],
#             "inverse": false,
#             "name": "",
#             "show": true
#         }
#     ],
#     "series_id": 6769535,

# %%
# 行业分布 - 饼图
from pyecharts import Pie
ind = []
jcount = []
ccount = []
elsesum_j = 0
elsesum_c = 0
for i in range(0,len(industry_top10)):
    if jobcount[i] >= 40:
        ind.append(industry_top10[i])
        jcount.append(job_count[i])
        ccount.append(company_count[i])
    else:
        elsesum_j += job_count[i]
        elsesum_c += company_count[i]
ind.append('其他')
jcount.append(elsesum_j)
ccount.append(elsesum_c)


pie = Pie('行业占比',subtitle = '行业-职位数',title_pos = 'center',title_top = '44%')
pie.add('',ind,jcount,radius=[40,75],is_label_show = 1)
pie
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="d75c6073923e47f5906430a9e113bcfb" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('d75c6073923e47f5906430a9e113bcfb'));
# var option =  {
#     "toolbox": {
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "show": true
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "backgroundColor": "#fff",
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14,
#             "color": "#fff"
#         },
#         "formatter": null,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "series_id": 8240375,
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "value": 98,
#                     "name": "\u91d1\u878d"
#                 },
#                 {
#                     "value": 66,
#                     "name": "\u79fb\u52a8\u4e92\u8054\u7f51"
#                 },
#                 {
#                     "value": 53,
#                     "name": "\u6570\u636e\u670d\u52a1"
#                 },
#                 {
#                     "value": 47,
#                     "name": "\u7535\u5b50\u5546\u52a1"
#                 },
#                 {
#                     "value": 45,
#                     "name": "O2O"
#                 },
#                 {
#                     "value": 95,
#                     "name": "\u5176\u4ed6"
#                 }
#             ],
#             "seriesId": 8240375,
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "name": "",
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "position": "outside",
#                     "formatter": "{b}: {d}%",
#                     "show": 1
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "position": null,
#                     "show": true
#                 }
#             },
#             "roseType": null
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12,
#                 "color": "#aaa"
#             },
#             "text": "\u884c\u4e1a\u5360\u6bd4",
#             "top": "44%",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#000"
#             },
#             "left": "center",
#             "subtext": "\u884c\u4e1a-\u804c\u4f4d\u6570"
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u91d1\u878d",
#                 "\u79fb\u52a8\u4e92\u8054\u7f51",
#                 "\u6570\u636e\u670d\u52a1",
#                 "\u7535\u5b50\u5546\u52a1",
#                 "O2O",
#                 "\u5176\u4ed6"
#             ],
#             "orient": "horizontal",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             },
#             "left": "center",
#             "show": true,
#             "selectedMode": "multiple"
#         }
#     ]
# };
# myChart.setOption(option);
#
#     });
# </script>

# %% [markdown]
# # 各行业排名前十的公司

# %%
inds = ['金融','移动互联网','数据服务','电子商务','O2O']
for ind in inds:
    df = data[data['industryField'] == ind].groupby('companyShortName').agg({'count':pd.Series.count})\
    .sort_values(['count'], ascending=[0])
    print([ind,list(df.index)[:5]])
# Out:
# ['金融', ['蚂蚁金服集团', '无秘', '奇虎360金融', '网贷之家', '广州银行信用卡中心']]
# ['移动互联网', ['金山办公软件', '小米', '上海宏鹿信息技术服务有限公司', '最右', '滴滴出行']]
# ['数据服务', ['搜狗', '集奥聚合（GEO）', '今日头条', '极光', '百度']]
# ['电子商务', ['京东商城', '欢乐逛', '蜜芽', '同程旅游', '网易']]
# ['O2O', ['美团点评', '人人车', '链家', '首汽约车', '二维火']]

# %% [markdown]
# # 各城市频率统计

# %%
from pyecharts import Bar,Line,Overlap
# 按城市分类,对城市的出现次数进行降序排序
city = data.groupby('city').agg({'positionName': pd.Series.count,'companyShortName': pd.Series.nunique})
city = city.sort_values(['positionName', 'companyShortName'], ascending=[0, 0])
# 取出出现最频繁的十个城市
city_top10 = list(city.index)[:10]
job_count = list(map(int, city['positionName']))[:10]   # 职位计数
company_count = list(map(int, city['companyShortName']))[:10]   # 公司计数
job_per_com = []    # 每个行业对该岗位的需求程度
for i in range(0, len(city_top10)):
    job_per_com.append(round(job_count[i]/company_count[i], 2))
city
# Out:
#       positionName  companyShortName
# city
# 北京             242               134
# 上海              69                55
# 杭州              35                22
# 深圳              34                23
# 广州              16                13
# 武汉              12                11
# 成都              11                 8
# 厦门               8                 6
# 南京               6                 4
# 苏州               4                 3
# 长沙               3                 3
# 天津               2                 2
# 东莞               1                 1
# 佛山               1                 1
# 哈尔滨              1                 1
# 济南               1                 1
# 珠海               1                 1
# 福州               1                 1
# 贵阳               1                 1
# 郑州               1                 1

# %%
company_count
# Out:
# [134, 55, 22, 23, 13, 11, 8, 6, 4, 3]

# %%
bar = Bar('城市分布', subtitle='城市-职位数/公司数')
bar.add('职位数量', x_axis=city_top10, xaxis_interval=0, bar_category_gap=0,
        y_axis=job_count, is_label_show=1)
bar.add('公司数量', is_label_show=1,
        x_axis=city_top10, xaxis_interval=0, xaxis_rotate=-45,
        y_axis=company_count, yaxis_name='职位数量', yaxis_force_interval=50,
        yaxis_name_gap=40, datazoom_orient = 'horizontal',
        datazoom_type = 'both', is_stack=0, bar_category_gap=20)

line = Line()
line.add('',x_axis=city_top10, y_axis=job_per_com, line_width=2,
        xaxis_interval=0, is_label_show=1,
        yaxis_max=2.5, yaxis_force_interval=0.5)

overlap = Overlap()
overlap.add(bar)
overlap.add(line, yaxis_index=1, is_add_yaxis=True)
overlap
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="7e5efbd6cee8423ab27546f3f9b32b02" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('7e5efbd6cee8423ab27546f3f9b32b02'));
# var option =  {
#     "toolbox": {
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 242,
#                 69,
#                 35,
#                 34,
#                 16,
#                 12,
#                 11,
#                 8,
#                 6,
#                 4
#             ],
#             "seriesId": 2697100,
#             "stack": "",
#             "barCategoryGap": 0,
#             "name": "\u804c\u4f4d\u6570\u91cf",
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "position": "top",
#                     "formatter": null,
#                     "show": 1
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "position": null,
#                     "show": true
#                 }
#             }
#         },
#         {
#             "type": "bar",
#             "data": [
#                 134,
#                 55,
#                 22,
#                 23,
#                 13,
#                 11,
#                 8,
#                 6,
#                 4,
#                 3
#             ],
#             "seriesId": 2697100,
#             "stack": "",
#             "barCategoryGap": 20,
#             "name": "\u516c\u53f8\u6570\u91cf",
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "position": "top",
#                     "formatter": null,
#                     "show": 1
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "position": null,
#                     "show": true
#                 }
#             }
#         },
#         {
#             "type": "line",
#             "stack": "",
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "position": "top",
#                     "formatter": null,
#                     "show": 1
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "position": null,
#                     "show": true
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "type": "solid",
#                     "width": 2,
#                     "curveness": 0,
#                     "color": null,
#                     "opacity": 1
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "data": [
#                 1.81,
#                 1.25,
#                 1.59,
#                 1.48,
#                 1.23,
#                 1.09,
#                 1.38,
#                 1.33,
#                 1.5,
#                 1.33
#             ],
#             "yAxisIndex": 1,
#             "areaStyle": {},
#             "seriesId": 2697100,
#             "smooth": false,
#             "name": "",
#             "markLine": {
#                 "data": []
#             },
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "step": false,
#             "showSymbol": true
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "nameGap": 40,
#             "nameLocation": "middle",
#             "position": null,
#             "max": null,
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "min": null,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 },
#                 "rotate": 0,
#                 "formatter": "{value} ",
#                 "margin": 8
#             },
#             "inverse": false,
#             "name": "\u804c\u4f4d\u6570\u91cf",
#             "show": true,
#             "interval": 50
#         },
#         {
#             "type": "value",
#             "nameGap": 25,
#             "nameLocation": "middle",
#             "position": null,
#             "max": 2.5,
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "min": null,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "formatter": "{value} ",
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 },
#                 "margin": 8
#             },
#             "inverse": false,
#             "name": "",
#             "show": true,
#             "interval": 0.5
#         }
#     ],
#     "xAxis": [
#         {
#             "type": "category",
#             "nameGap": 25,
#             "nameLocation": "middle",
#             "position": null,
#             "max": null,
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "min": null,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "margin": 8,
#                 "rotate": -45,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "data": [
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u676d\u5dde",
#                 "\u6df1\u5733",
#                 "\u5e7f\u5dde",
#                 "\u6b66\u6c49",
#                 "\u6210\u90fd",
#                 "\u53a6\u95e8",
#                 "\u5357\u4eac",
#                 "\u82cf\u5dde"
#             ],
#             "inverse": false,
#             "name": "",
#             "show": true
#         }
#     ],
#     "series_id": 2697100,
#     "backgroundColor": "#fff",
#     "title": [
#         {

# %%
locate = []
jcount = []
ccount = []
elsesum_j = 0
elsesum_c = 0
for i in range(0,len(city_top10)):
    if job_count[i] >= 15:
        locate.append(city_top10[i])
        jcount.append(job_count[i])
        ccount.append(company_count[i])
    else:
        elsesum_j += job_count[i]
        elsesum_c += company_count[i]
locate.append('其他')
jcount.append(elsesum_j)
ccount.append(elsesum_c)

pie = Pie('城市占比',subtitle = '城市-职位数',title_pos = 'center',title_top = '44%')
pie.add('',locate,jcount,radius=[40,75],is_label_show = 1)
pie
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="b407e514f7e446168cd7f9c4a8f7478c" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('b407e514f7e446168cd7f9c4a8f7478c'));
# var option =  {
#     "toolbox": {
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "show": true
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "backgroundColor": "#fff",
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14,
#             "color": "#fff"
#         },
#         "formatter": null,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "series_id": 6669901,
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "value": 242,
#                     "name": "\u5317\u4eac"
#                 },
#                 {
#                     "value": 69,
#                     "name": "\u4e0a\u6d77"
#                 },
#                 {
#                     "value": 35,
#                     "name": "\u676d\u5dde"
#                 },
#                 {
#                     "value": 34,
#                     "name": "\u6df1\u5733"
#                 },
#                 {
#                     "value": 16,
#                     "name": "\u5e7f\u5dde"
#                 },
#                 {
#                     "value": 41,
#                     "name": "\u5176\u4ed6"
#                 }
#             ],
#             "seriesId": 6669901,
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "name": "",
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "position": "outside",
#                     "formatter": "{b}: {d}%",
#                     "show": 1
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "position": null,
#                     "show": true
#                 }
#             },
#             "roseType": null
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12,
#                 "color": "#aaa"
#             },
#             "text": "\u57ce\u5e02\u5360\u6bd4",
#             "top": "44%",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#000"
#             },
#             "left": "center",
#             "subtext": "\u57ce\u5e02-\u804c\u4f4d\u6570"
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u676d\u5dde",
#                 "\u6df1\u5733",
#                 "\u5e7f\u5dde",
#                 "\u5176\u4ed6"
#             ],
#             "orient": "horizontal",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             },
#             "left": "center",
#             "show": true,
#             "selectedMode": "multiple"
#         }
#     ]
# };
# myChart.setOption(option);
#
#     });
# </script>

# %%
# 前五的城市,每个城市的公司(top10)
citys= ['北京', '上海', '杭州', '深圳', '广州']
for c in citys:
    df = data[data['city']==c].groupby('companyShortName').agg({'count':pd.Series.count})\
        .sort_values(['count'], ascending=[0])
    print([c, list(df.index)[:5]])
# Out:
# ['北京', ['美团点评', '京东商城', '小米', '搜狗', '好未来']]
# ['上海', ['上海宏鹿信息技术服务有限公司', '网贷之家', '极光', '上海晋景数据', '华院数据']]
# ['杭州', ['蚂蚁金服集团', '微拍堂', '浙江执御信息技术有限公司', '浙报集团', '魔蝎科技']]
# ['深圳', ['无秘', '随手科技', '试金石信用', '乐信', '极光']]
# ['广州', ['广州银行信用卡中心', '蓝盾信息安全技术股份有限公司', 'Bigo', 'Edison Inc', 'vivo']]

# %%
companySize = data.groupby('companySize').agg({'positionName': pd.Series.count,'companyShortName': pd.Series.nunique})
companySize = companySize.sort_values(['positionName', 'companyShortName'], ascending=[0, 0])
companySize_top10 = list(companySize.index)[:10]
job_count = list(map(int, companySize['positionName']))[:10]   # 职位计数
company_count = list(map(int, companySize['companyShortName']))[:10]   # 公司计数
job_per_com = []    
for i in range(0, len(companySize_top10)):
    job_per_com.append(round(job_count[i]/company_count[i], 2))
companySize
# Out:
#              positionName  companyShortName
# companySize
# 2000人以上               161                63
# 150-500人              113                81
# 500-2000人              93                59
# 50-150人                61                48
# 15-50人                 19                18
# 少于15人                   3                 2

# %%
company_count
# Out:
# [63, 81, 59, 48, 18, 2]

# %%
bar = Bar('规模分布','公司规模-职位数/公司数')
bar.add('职位数量', x_axis=companySize_top10, xaxis_interval=0, bar_category_gap=20,
        y_axis=job_count, is_label_show=1)
bar.add('公司数量', is_label_show=1,
        x_axis=companySize_top10, xaxis_rotate=-45,
        y_axis=company_count, yaxis_name='职位数量', yaxis_force_intervel=30,yaxis_name_gap=40,
        datazoom_orient = 'horizontal',datazoom_type = 'both',
        bar_category_gap=20)

line = Line()
line.add('',x_axis=companySize_top10,y_axis=j_per_com,line_width=2,is_label_show=True)
overlap = Overlap()
overlap.add(bar)
overlap.add(line,yaxis_index=1,is_add_yaxis=True)
overlap
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="bcaf80d229604f64b619d2beea098008" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('bcaf80d229604f64b619d2beea098008'));
# var option =  {
#     "toolbox": {
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 161,
#                 113,
#                 93,
#                 61,
#                 19,
#                 3
#             ],
#             "seriesId": 5588712,
#             "stack": "",
#             "barCategoryGap": 20,
#             "name": "\u804c\u4f4d\u6570\u91cf",
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "position": "top",
#                     "formatter": null,
#                     "show": 1
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "position": null,
#                     "show": true
#                 }
#             }
#         },
#         {
#             "type": "bar",
#             "data": [
#                 63,
#                 81,
#                 59,
#                 48,
#                 18,
#                 2
#             ],
#             "seriesId": 5588712,
#             "stack": "",
#             "barCategoryGap": 20,
#             "name": "\u516c\u53f8\u6570\u91cf",
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "position": "top",
#                     "formatter": null,
#                     "show": 1
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "position": null,
#                     "show": true
#                 }
#             }
#         },
#         {
#             "type": "line",
#             "stack": "",
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "position": "top",
#                     "formatter": null,
#                     "show": true
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "position": null,
#                     "show": true
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "type": "solid",
#                     "width": 2,
#                     "curveness": 0,
#                     "color": null,
#                     "opacity": 1
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "data": [
#                 2.56,
#                 1.4,
#                 1.58,
#                 1.27,
#                 1.06,
#                 1.5
#             ],
#             "yAxisIndex": 1,
#             "areaStyle": {},
#             "seriesId": 5588712,
#             "smooth": false,
#             "name": "",
#             "markLine": {
#                 "data": []
#             },
#             "xAxisIndex": 0,
#             "symbol": "emptyCircle",
#             "step": false,
#             "showSymbol": true
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "nameGap": 40,
#             "nameLocation": "middle",
#             "position": null,
#             "max": null,
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "min": null,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 },
#                 "rotate": 0,
#                 "formatter": "{value} ",
#                 "margin": 8
#             },
#             "inverse": false,
#             "name": "\u804c\u4f4d\u6570\u91cf",
#             "show": true
#         },
#         {
#             "type": "value",
#             "nameGap": 25,
#             "nameLocation": "middle",
#             "position": null,
#             "max": null,
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "min": null,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "formatter": "{value} ",
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 },
#                 "margin": 8
#             },
#             "inverse": false,
#             "name": "",
#             "show": true
#         }
#     ],
#     "xAxis": [
#         {
#             "type": "category",
#             "nameGap": 25,
#             "nameLocation": "middle",
#             "position": null,
#             "max": null,
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "min": null,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "margin": 8,
#                 "rotate": -45,
#                 "textStyle": {
#                     "fontSize": 12,
#                     "color": "#000"
#                 }
#             },
#             "data": [
#                 "2000\u4eba\u4ee5\u4e0a",
#                 "150-500\u4eba",
#                 "500-2000\u4eba",
#                 "50-150\u4eba",
#                 "15-50\u4eba",
#                 "\u5c11\u4e8e15\u4eba"
#             ],
#             "inverse": false,
#             "name": "",
#             "show": true
#         }
#     ],
#     "series_id": 5588712,
#     "backgroundColor": "#fff",
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12,
#                 "color": "#aaa"
#             },
#             "text": "\u89c4\u6a21\u5206\u5e03",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#000"
#             },
#             "left": "auto",
#             "subtext": "\u516c\u53f8\u89c4\u6a21-\u804c\u4f4d\u6570/\u516c\u53f8\u6570"

# %%
size = []
jcount = []
ccount = []
for i in range(0,len(companySize_top10)):
    if companySize_top10[i] != 'null':
        size.append(companySize_top10[i])
        jcount.append(int(job_count[i]))
        ccount.append(int(company_count[i]))

# %%
pie = Pie('规模占比',subtitle = '公司规模-职位数',title_pos = 'center',title_top = '44%')
pie.add('',size,jcount,radius=[40,75],is_label_show = 1)
pie
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="af1505128bcd4ebdb17075e454d18844" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('af1505128bcd4ebdb17075e454d18844'));
# var option =  {
#     "toolbox": {
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "show": true
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "backgroundColor": "#fff",
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14,
#             "color": "#fff"
#         },
#         "formatter": null,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "series_id": 8613949,
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "value": 161,
#                     "name": "2000\u4eba\u4ee5\u4e0a"
#                 },
#                 {
#                     "value": 113,
#                     "name": "150-500\u4eba"
#                 },
#                 {
#                     "value": 93,
#                     "name": "500-2000\u4eba"
#                 },
#                 {
#                     "value": 61,
#                     "name": "50-150\u4eba"
#                 },
#                 {
#                     "value": 19,
#                     "name": "15-50\u4eba"
#                 },
#                 {
#                     "value": 3,
#                     "name": "\u5c11\u4e8e15\u4eba"
#                 }
#             ],
#             "seriesId": 8613949,
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "name": "",
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#000"
#                     },
#                     "position": "outside",
#                     "formatter": "{b}: {d}%",
#                     "show": 1
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#fff"
#                     },
#                     "position": null,
#                     "show": true
#                 }
#             },
#             "roseType": null
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12,
#                 "color": "#aaa"
#             },
#             "text": "\u89c4\u6a21\u5360\u6bd4",
#             "top": "44%",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#000"
#             },
#             "left": "center",
#             "subtext": "\u516c\u53f8\u89c4\u6a21-\u804c\u4f4d\u6570"
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "2000\u4eba\u4ee5\u4e0a",
#                 "150-500\u4eba",
#                 "500-2000\u4eba",
#                 "50-150\u4eba",
#                 "15-50\u4eba",
#                 "\u5c11\u4e8e15\u4eba"
#             ],
#             "orient": "horizontal",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             },
#             "left": "center",
#             "show": true,
#             "selectedMode": "multiple"
#         }
#     ]
# };
# myChart.setOption(option);
#
#     });
# </script>

# %%
for size in companySize_top10:
    df = data[data['companySize']==size].groupby('companyShortName').agg({'count':pd.Series.count})\
    .sort_values(['count'],ascending=[0])
    print([size,list(df.index)[:5]])
# Out:
# ['2000人以上', ['美团点评', '蚂蚁金服集团', '京东商城', '小米', '金山办公软件']]
# ['150-500人', ['无秘', '集奥聚合（GEO）', '极光', '数美', '网贷之家']]
# ['500-2000人', ['今日头条', '奇虎360金融', '美图公司', '新华网', 'Gridsum 国双']]
# ['50-150人', ['上海宏鹿信息技术服务有限公司', '最右', '商询科技', '试金石信用', '慕课网']]
# ['15-50人', ['小库科技', 'ARKie', '深睿医疗', '阡寻', '轻趣']]
# ['少于15人', ['上海晋景数据', '北京跬步众成信息技术有限公司']]

# %%
from pyecharts import WordCloud
def count_word(word_list):
    '''
    词频统计
    '''
    cnt = dict()
    for word in word_list:
        if word != 'null':
            if word in cnt.keys():
                cnt[word] += 1
            else:
                cnt[word] = 1
    return cnt


def wordcloud(word_list):
    dic = count_word(word_list)
    word = list(dic.keys())
    freq = list(dic.values())
    wordc = WordCloud(width=900, height=450)
    wordc.add("福利", word, freq, word_size_range=[15,100], shape='circle')
    #输出top10及词频
    sort_dic = sorted(dic.items(), key = lambda asd:asd[1],reverse = True)
    for i in range(0,10):
        print(i+1,sort_dic[i])
    return wordc

# %%
#tag_词云
df = data[data['companyLabelList'] != '']['companyLabelList']
# print(list(df))
tag_list = list(df)
tag_list_all = []
for i in range(0,len(tag_list)):
    tag_split = tag_list[i].split(',')
    for each in tag_split:
        if each != '':
            tag_list_all.append(each)
wordcloud(tag_list_all)
# Out:
# 1 ('带薪年假', 170)
# 2 ('绩效奖金', 141)
# 3 ('股票期权', 121)
# 4 ('技能培训', 108)
# 5 ('节日礼物', 107)
# 6 ('年底双薪', 98)
# 7 ('岗位晋升', 95)
# 8 ('五险一金', 92)
# 9 ('扁平管理', 68)
# 10 ('年度旅游', 53)
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#          }
#     });
# </script>
# <div id="f144e6c9f369451e9d12d6efaf4e79dc" style="width:900px; height:450px;"></div>
#
# <script>
#     require([ 'echarts', 'wordcloud' ],function(ec){
# 	var myChart = ec.init(document.getElementById('f144e6c9f369451e9d12d6efaf4e79dc'));
# var option =  {
#     "toolbox": {
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "show": true
#     },
#     "backgroundColor": "#fff",
#     "tooltip": {},
#     "series_id": 68120,
#     "series": [
#         {
#             "type": "wordCloud",
#             "data": [
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,99,85)"
#                         }
#                     },
#                     "value": 3,
#                     "name": "\u56fd\u9645\u5316\u56e2\u961f"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,0,39)"
#                         }
#                     },
#                     "value": 4,
#                     "name": "\u725b\u4eba\u591a"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,118,73)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u5e26\u85aa\u4f11\u5047"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,33,95)"
#                         }
#                     },
#                     "value": 34,
#                     "name": "\u514d\u8d39\u73ed\u8f66"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,123,68)"
#                         }
#                     },
#                     "value": 4,
#                     "name": "\u664b\u5347\u7a7a\u95f4\u5927"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(142,89,51)"
#                         }
#                     },
#                     "value": 141,
#                     "name": "\u7ee9\u6548\u5956\u91d1"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(98,67,92)"
#                         }
#                     },
#                     "value": 2,
#                     "name": "\u56e2\u961f\u65c5\u6e38"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,4,91)"
#                         }
#                     },
#                     "value": 23,
#                     "name": "\u901a\u8baf\u6d25\u8d34"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,23,38)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u516d\u9669\u4e00\u91d1"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(121,6,110)"
#                         }
#                     },
#                     "value": 2,
#                     "name": "BAT\u6280\u672f"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(70,68,56)"
#                         }
#                     },
#                     "value": 2,
#                     "name": "\u963f\u91cc\u5927\u725b"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,46,47)"
#                         }
#                     },
#                     "value": 121,
#                     "name": "\u80a1\u7968\u671f\u6743"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(134,105,17)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u56e2\u7ed3\u53cb\u7231"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,104,82)"
#                         }
#                     },
#                     "value": 2,
#                     "name": "\u516c\u53f8\u5b9e\u529b\u96c4\u539a"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,107,121)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u8f66\u5382\u5408\u4f5c"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(93,101,12)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u8865\u5145\u533b\u7597\u4fdd\u9669"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,27,49)"
#                         }
#                     },
#                     "value": 53,
#                     "name": "\u5e74\u5ea6\u65c5\u6e38"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(38,77,20)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u4e00\u516c\u91cc\u5de5\u4f5c\u5708"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,152,56)"
#                         }
#                     },
#                     "value": 2,
#                     "name": "\u4e03\u9669\u4e00\u91d1"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,17,126)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u56ed\u6797\u5f0f\u529e\u516c"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(14,151,145)"
#                         }
#                     },
#                     "value": 23,
#                     "name": "\u5e74\u7ec8\u5206\u7ea2"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(31,119,64)"
#                         }
#                     },
#                     "value": 3,
#                     "name": "\u7ee9\u6548\u5956\u91d1 "
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,45,26)"
#                         }
#                     },
#                     "value": 2,
#                     "name": "\u4eba\u624d\u516c\u5bd3"
#                 },
#                 {
#                     "textStyle": {
#                         "norma

# %%
#判断str是否含有中文 True or False
def check_contain_chinese(check_str):
    for ch in check_str:
        if u'\u4e00' <= ch <= u'\u9fff':
            return True
    return False
#字符筛选器：包含返回True，否则返回False
def if_contains(s):
    value = False
    filter = ['数据','岗位','学历','互联网','计算机','全日制','and','熟练','责任心']
    for each in filter:
        if each in s:
            value = True
    return value

# %%
#合并description字段->一个str，分词，并输出词云以及词频top10
import jieba 
def des_cloud(des_list):
    description_all = ''
    for each in des_list:
            if each != '':
                description_all += each+','
    seg_list = jieba.cut(description_all,cut_all=True)
    seg = []
    for i in seg_list:
        if check_contain_chinese(i):
            if len(i)>2 and not if_contains(i):
                seg.append(i)
        else:
            if ((len(i) > 1 and i.isdigit() != True) or (i == 'R')) and (not if_contains(i)):
                seg.append(str.upper(i)) 
    wordc = wordcloud(seg)
    return wordc

# %%
#所需技术——关键词
df = data[(data['job_description'] != '')]['job_description']
des_list = list(df)
des_cloud(des_list)
# Out:
# 1 ('PYTHON', 370)
# 2 ('HADOOP', 259)
# 3 ('SPARK', 233)
# 4 ('JAVA', 225)
# 5 ('R', 155)
# 6 ('统计学', 147)
# 7 ('HIVE', 143)
# 8 ('分布式', 139)
# 9 ('SQL', 132)
# 10 ('LINUX', 116)
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#          }
#     });
# </script>
# <div id="9fe26c74626943f59da0731cd72257bd" style="width:900px; height:450px;"></div>
#
# <script>
#     require([ 'echarts', 'wordcloud' ],function(ec){
# 	var myChart = ec.init(document.getElementById('9fe26c74626943f59da0731cd72257bd'));
# var option =  {
#     "toolbox": {
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "show": true
#     },
#     "backgroundColor": "#fff",
#     "tooltip": {},
#     "series_id": 3762453,
#     "series": [
#         {
#             "type": "wordCloud",
#             "data": [
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(25,96,20)"
#                         }
#                     },
#                     "value": 9,
#                     "name": "MONGODB"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,147,69)"
#                         }
#                     },
#                     "value": 3,
#                     "name": "\u81ea\u7531\u652f\u914d"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(76,70,73)"
#                         }
#                     },
#                     "value": 225,
#                     "name": "JAVA"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(19,81,43)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u623f\u4ea7\u4fe1\u606f"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,134,133)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u591a\u65b9\u9762"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(13,84,130)"
#                         }
#                     },
#                     "value": 2,
#                     "name": "\u8de8\u56fd\u4f01\u4e1a"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,32,134)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u8fdc\u7a0b\u7ba1\u7406"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,25,117)"
#                         }
#                     },
#                     "value": 2,
#                     "name": "\u6295\u878d\u8d44"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(105,89,92)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "AMP"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,89,43)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u4fe1\u606f\u79d1\u5b66"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,109,57)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "BASH"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,137,112)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u6bd5\u4e1a\u8bc1"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(0,78,109)"
#                         }
#                     },
#                     "value": 2,
#                     "name": "\u77e5\u96be\u800c\u8fdb"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,32,18)"
#                         }
#                     },
#                     "value": 5,
#                     "name": "\u5b9e\u65bd\u65b9\u6848"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(131,106,91)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "TALKINGDATA"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(125,124,125)"
#                         }
#                     },
#                     "value": 2,
#                     "name": "\u4e13\u5bb6\u7ecf"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,160,24)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "PYTHONJAVANODEJS"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,2,111)"
#                         }
#                     },
#                     "value": 2,
#                     "name": "\u6027\u884c\u4e3a"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(46,21,34)"
#                         }
#                     },
#                     "value": 2,
#                     "name": "RDD"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,79,148)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u91d1\u878d\u4fdd\u9669"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(41,2,54)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "\u4e2d\u56fd\u79d1\u5b66\u9662"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(104,127,79)"
#                         }
#                     },
#                     "value": 3,
#                     "name": "AMBARI"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,105,118)"
#                         }
#                     },
#                     "value": 3,
#                     "name": "MINING"
#                 },
#                 {
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(112,19,110)"
#                         }
#                     },
#                     "value": 1,
#                     "name": "OR"
#                 },
#                 {
